# %%
###Write a function that takes two integers as input and returns their division. 
# Use try, except, and finally blocks to handle division by zero and print an 
# appropriate message.

def division(num1,num2):
    try:
        result = num1/num2
    except ValueError:
        print("Give input as integers onlys")
    except ZeroDivisionError:
        print("Make sure the second number is not zero")
    except Exception as ex:
        print(ex)
    else:
        print(result)
    finally:
        print("The end of the program")

division(2,0)
# Out:
# Make sure the second number is not zero
# The end of the program

# %%
### Write a function that reads the contents of a file named `data.txt`. 
# Use try, except, and finally blocks to handle file not found errors 
# and ensure the file is properly closed.

def checkFile(File):
    
    File = None

    try:
        file = open(File,mode='r')
        Content = file.read()
    except FileNotFoundError:
        print("There is no such file")
    except Exception as ex:
        print(ex)
    else:
        print(Content)
    finally:
        if File is not None:
            file.close()
            print("The file has closed")


value = "data1.txt"
checkFile(value)
# Out:
# expected str, bytes or os.PathLike object, not NoneType

# %%
### Write a function that takes a list of integers and returns their sum. 
# Use try, except, and finally blocks to handle TypeError if a non-integer
# value is encountered and print an appropriate message.

def sum(listOfNumber):
    count = 0
    try:
        for number in listOfNumber:
            count += number
    except Exception as ex:
        print(ex)
    else:
        print(count)

sum([1,2,3,4])
# Out:
# 10

# %%
### Write a function that prompts the user to enter an integer. 
# Use try, except, and finally blocks to handle ValueError 
# if the user enters a non-integer value and print an appropriate message.

def checkInteger(value):

    try:
        result = value*1
    except Exception as ex:
        print(ex)
    else:
        print(f"The value is {type(result)}")
    finally:
        print("The program has ended")

checkInteger(5)
# Out:
# The value is <class 'int'>
# The program has ended

# %%
### Write a function that takes a dictionary and a key as input and 
# returns the value associated with the key. Use try, except, and finally 
# blocks to handle KeyError if the key is not found in the dictionary and 
# print an appropriate message.

def keyValue(data):

    try:
        for key in data:
            value = data[key]
    except Exception as ex:
        print(ex)
    else:
        print(value)
    finally:
        print("The program has ended")

dict = {
    'name' : 'Rahul',
    'age'  : 26
}


keyValue(dict)
# Out:
# 26
# The program has ended

# %%
### Write a function that performs nested exception handling. 
# It should first attempt to convert a string to an integer, 
# and then attempt to divide by that integer. Use nested try, except, 
# and finally blocks to handle ValueError and ZeroDivisionError 
# and print appropriate messages.

def nestedException(value):

    try:
        convertion = int(value)
        try:
            result = 10/convertion
        except ZeroDivisionError:
            print("Dont enter number 0")
        else:
            print(result)
    except Exception as ex:
        print(ex)
    finally:
        print("The program has ended")

nestedException("1")
# Out:
# 10.0
# The program has ended

# %%
### Write a function that takes a list and an index as input and returns the 
# element at the given index. Use try, except, and finally blocks to 
# handle IndexError if the index is out of range and print an appropriate message.

def indexx(numbers,index):

    try:
        print(numbers[index])
    except IndexError:
        print("The index is out of bounds")
    finally:
        print("End of program")

data = [1,6,4,2,7,9,10,15,8]

indexx(data,9)
# Out:
# The index is out of bounds
# End of program
