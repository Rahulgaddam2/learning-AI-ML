# %%
### Magic Methods
### Magic methods are special methods in Python that start and end with double underscores __
### They allow you to define how objects behave with built-in Python operations.

### examples : __init__ -> when object is created
###            __str__  -> when you print obj , and more

# %%
### basic magic methods

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

person1 = Person("Rahul",25)
print(person1)

# %%
### basic magic methods
### overiding the __str__ method
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name}, {self.age} years old"
    
person1 = Person("Rahul",25)
print(person1)
# Out:
# Rahul, 25 years old
