# %%
from package.subPackage.greet import welcome

print(welcome("Rahul"))
# Out:
# welcome to my world Rahul
# None

# %%
from package.maths import addition  ### This is my own module which i created in package folder and also remember always add __init__.py file in the package folder

print(addition(4,5))
# Out:
# 9

# %%
from math import *

print(round(4.9))
# Out:
# 5

# %%
import numpy as np

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
### importing only required built in functions from module

from math import sqrt,pi

print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
### Modules and packages in python

import math ## mathematical module in python

result = math.sqrt(16)
print(result)
# Out:
# 4.0
